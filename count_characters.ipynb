# %% [markdown]
# # Project 9: Count Characters in a String

# %%
# This project teaches how to use len() to count characters.

# %%
# Step 1: Ask the user for a string
user_text = input("Enter a text: ")
